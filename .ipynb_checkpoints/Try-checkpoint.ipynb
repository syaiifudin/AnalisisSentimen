# %%
import pandas as pd
import re #regex library
import nltk
import string
# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# %%
TWEET_DATA = pd.read_excel('datasetojol.xlsx')
TWEET_DATA
# Out:
#      Unnamed: 0 created_at        username  \
# 0             1 2022-07-17      donavistaj
# 1             2 2022-07-17   hezalnutlatte
# 2             3 2022-07-17      dillapatma
# 3             4 2022-07-17   stradivarians
# 4             5 2022-07-17      ojolwinwis
# ..          ...        ...             ...
# 402         403 2022-07-17       Ruthliees
# 403         404 2022-07-17        seakyoto
# 404         405 2022-07-17    hangwhyunjin
# 405         406 2022-07-17  NandaClaudia13
# 406         407 2022-07-17        njlxxxxx
#
#                                                   text  label
# 0    @riezf @kresseek santai, ada gojek chat atau w...      1
# 1    @ prifad gua naek gojek dulu ye, semoga turun2...      1
# 2                    @kooalee Seperti gojek gue error😭     -1
# 3    Sementara beralih dulu jd grab user karena goj...     -1
# 4    Lah Minggu malah sepi order .tapi sesepi gojek...     -1
# ..                                                 ...    ...
# 402  @Aleenavy Lah, kan situ yang bolak-balik jadi ...      1
# 403  malem-malem otakku berpikir besok naik bus rut...      1
# 404    @SBTHANSKZ betull, ak selama ada grab sih jalan      1
# 405  RT @refalhady: Apa perlu aku jadi abang grab, ...      1
# 406  Tu belum ckp pasal transport. Bas dgn grab pun...     -1
#
# [407 rows x 5 columns]

# %%
##case folding
TWEET_DATA['text'] = TWEET_DATA['text'].str.lower()
TWEET_DATA
# Out:
#      Unnamed: 0 created_at        username  \
# 0             1 2022-07-17      donavistaj
# 1             2 2022-07-17   hezalnutlatte
# 2             3 2022-07-17      dillapatma
# 3             4 2022-07-17   stradivarians
# 4             5 2022-07-17      ojolwinwis
# ..          ...        ...             ...
# 402         403 2022-07-17       Ruthliees
# 403         404 2022-07-17        seakyoto
# 404         405 2022-07-17    hangwhyunjin
# 405         406 2022-07-17  NandaClaudia13
# 406         407 2022-07-17        njlxxxxx
#
#                                                   text  label
# 0    @riezf @kresseek santai, ada gojek chat atau w...      1
# 1    @ prifad gua naek gojek dulu ye, semoga turun2...      1
# 2                    @kooalee seperti gojek gue error😭     -1
# 3    sementara beralih dulu jd grab user karena goj...     -1
# 4    lah minggu malah sepi order .tapi sesepi gojek...     -1
# ..                                                 ...    ...
# 402  @aleenavy lah, kan situ yang bolak-balik jadi ...      1
# 403  malem-malem otakku berpikir besok naik bus rut...      1
# 404    @sbthanskz betull, ak selama ada grab sih jalan      1
# 405  rt @refalhady: apa perlu aku jadi abang grab, ...      1
# 406  tu belum ckp pasal transport. bas dgn grab pun...     -1
#
# [407 rows x 5 columns]

# %%
##pengahpusan simbol
def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_tweet_special)
#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

TWEET_DATA['text'] = TWEET_DATA['text'].apply(remove_singl_char)
TWEET_DATA['created_at'] = TWEET_DATA['created_at'].apply(lambda a: pd.to_datetime(a).date())
TWEET_DATA
# Out:
#      Unnamed: 0  created_at        username  \
# 0             1  2022-07-17      donavistaj
# 1             2  2022-07-17   hezalnutlatte
# 2             3  2022-07-17      dillapatma
# 3             4  2022-07-17   stradivarians
# 4             5  2022-07-17      ojolwinwis
# ..          ...         ...             ...
# 402         403  2022-07-17       Ruthliees
# 403         404  2022-07-17        seakyoto
# 404         405  2022-07-17    hangwhyunjin
# 405         406  2022-07-17  NandaClaudia13
# 406         407  2022-07-17        njlxxxxx
#
#                                                   text  label
# 0    santai ada gojek chat atau worst case tinggal ...      1
# 1    prifad gua naek gojek dulu ye semoga turun lu ...      1
# 2                              seperti gojek gue error     -1
# 3    sementara beralih dulu jd grab user karena goj...     -1
# 4    lah minggu malah sepi order tapi sesepi gojek ...     -1
# ..                                                 ...    ...
# 402  lah kan situ yang bolakbalik jadi yang keliata...      1
# 403  malemmalem otakku berpikir besok naik bus rute...      1
# 404                betull ak selama ada grab sih jalan      1
# 405  rt apa perlu aku jadi abang grab supaya tau ja...      1
# 406  tu belum ckp pasal transport bas dgn grab pun ...     -1
#
# [407 rows x 5 columns]

# %%
df_preprocessed = TWEET_DATA.copy()
df_preprocessed = df_preprocessed.drop(columns=['created_at'])
df_preprocessed.head()
# Out:
#    Unnamed: 0       username  \
# 0           1     donavistaj
# 1           2  hezalnutlatte
# 2           3     dillapatma
# 3           4  stradivarians
# 4           5     ojolwinwis
#
#                                                 text  label
# 0  santai ada gojek chat atau worst case tinggal ...      1
# 1  prifad gua naek gojek dulu ye semoga turun lu ...      1
# 2                            seperti gojek gue error     -1
# 3  sementara beralih dulu jd grab user karena goj...     -1
# 4  lah minggu malah sepi order tapi sesepi gojek ...     -1

# %%
df_preprocessed
# Out:
#      Unnamed: 0        username  \
# 0             1      donavistaj
# 1             2   hezalnutlatte
# 2             3      dillapatma
# 3             4   stradivarians
# 4             5      ojolwinwis
# ..          ...             ...
# 402         403       Ruthliees
# 403         404        seakyoto
# 404         405    hangwhyunjin
# 405         406  NandaClaudia13
# 406         407        njlxxxxx
#
#                                                   text  label
# 0    santai ada gojek chat atau worst case tinggal ...      1
# 1    prifad gua naek gojek dulu ye semoga turun lu ...      1
# 2                              seperti gojek gue error     -1
# 3    sementara beralih dulu jd grab user karena goj...     -1
# 4    lah minggu malah sepi order tapi sesepi gojek ...     -1
# ..                                                 ...    ...
# 402  lah kan situ yang bolakbalik jadi yang keliata...      1
# 403  malemmalem otakku berpikir besok naik bus rute...      1
# 404                betull ak selama ada grab sih jalan      1
# 405  rt apa perlu aku jadi abang grab supaya tau ja...      1
# 406  tu belum ckp pasal transport bas dgn grab pun ...     -1
#
# [407 rows x 4 columns]

# %%
#tokenisasi 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_preprocessed['tweet_tokens'] = df_preprocessed['text'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df_preprocessed['tweet_tokens'].head())
print('\n\n\n')
# TWEET_DATA
# Out:
# Tokenizing Result :
#
# 0    [santai, ada, gojek, chat, atau, worst, case, ...
# 1    [prifad, gua, naek, gojek, dulu, ye, semoga, t...
# 2                         [seperti, gojek, gue, error]
# 3    [sementara, beralih, dulu, jd, grab, user, kar...
# 4    [lah, minggu, malah, sepi, order, tapi, sesepi...
# Name: tweet_tokens, dtype: object

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

df_preprocessed['tweet_tokens_fdist'] = df_preprocessed['tweet_tokens'].apply(freqDist_wrapper)
print('Frequency Tokens : \n') 
print(df_preprocessed['tweet_tokens_fdist'].head().apply(lambda x : x.most_common()))
# TWEET_DATA
# Out:
# Frequency Tokens :
#
# 0    [(santai, 1), (ada, 1), (gojek, 1), (chat, 1),...
# 1    [(prifad, 1), (gua, 1), (naek, 1), (gojek, 1),...
# 2     [(seperti, 1), (gojek, 1), (gue, 1), (error, 1)]
# 3    [(sementara, 1), (beralih, 1), (dulu, 1), (jd,...
# 4    [(order, 2), (jalan, 2), (lah, 1), (minggu, 1)...
# Name: tweet_tokens_fdist, dtype: object

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df_preprocessed['tweet_tokens_WSW'] = df_preprocessed['tweet_tokens'].apply(stopwords_removal) 


print(df_preprocessed['tweet_tokens_WSW'].head())
# Out:
# 0    [santai, gojek, chat, worst, case, tinggal, fi...
# 1    [prifad, gua, naek, gojek, ye, semoga, turun, ...
# 2                                  [gojek, gue, error]
# 3    [beralih, grab, user, gojek, yahudi, kaget, ba...
# 4    [minggu, sepi, order, sesepi, gojek, food, cs,...
# Name: tweet_tokens_WSW, dtype: object

# %%
normalizad_word = pd.read_csv("kamus_alay.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df_preprocessed['tweet_normalized'] = df_preprocessed['tweet_tokens_WSW'].apply(normalized_term)

print(df_preprocessed['tweet_normalized'].head())
# Out:
# 0    [santai, gojek, chat, worst, case, tinggal, fi...
# 1    [prifad, gua, naik, gojek, ye, semoga, turun, ...
# 2                                  [gojek, gue, error]
# 3    [beralih, grab, user, gojek, yahudi, kaget, ba...
# 4    [minggu, sepi, order, sesepi, gojek, food, cs,...
# Name: tweet_normalized, dtype: object

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
def stemming(dokumen):
    return [StemmerFactory().create_stemmer().stem(kata) for kata in dokumen if kata and kata.isascii()]
df_preprocessed['steeming'] = df_preprocessed['tweet_normalized'].apply(stemming)
print(df_preprocessed['steeming'].head())
# Out:
# 0    [santai, gojek, chat, worst, case, tinggal, fi...
# 1    [prifad, gua, naik, gojek, ye, moga, turun, du...
# 2                                  [gojek, gue, error]
# 3    [alih, grab, user, gojek, yahudi, kaget, baso,...
# 4    [minggu, sepi, order, sep, gojek, food, cs, pe...
# Name: steeming, dtype: object

# %%
df_preprocessed
# Out:
#      Unnamed: 0        username  \
# 0             1      donavistaj
# 1             2   hezalnutlatte
# 2             3      dillapatma
# 3             4   stradivarians
# 4             5      ojolwinwis
# ..          ...             ...
# 402         403       Ruthliees
# 403         404        seakyoto
# 404         405    hangwhyunjin
# 405         406  NandaClaudia13
# 406         407        njlxxxxx
#
#                                                   text  label  \
# 0    santai ada gojek chat atau worst case tinggal ...      1
# 1    prifad gua naek gojek dulu ye semoga turun lu ...      1
# 2                              seperti gojek gue error     -1
# 3    sementara beralih dulu jd grab user karena goj...     -1
# 4    lah minggu malah sepi order tapi sesepi gojek ...     -1
# ..                                                 ...    ...
# 402  lah kan situ yang bolakbalik jadi yang keliata...      1
# 403  malemmalem otakku berpikir besok naik bus rute...      1
# 404                betull ak selama ada grab sih jalan      1
# 405  rt apa perlu aku jadi abang grab supaya tau ja...      1
# 406  tu belum ckp pasal transport bas dgn grab pun ...     -1
#
#                                           tweet_tokens  \
# 0    [santai, ada, gojek, chat, atau, worst, case, ...
# 1    [prifad, gua, naek, gojek, dulu, ye, semoga, t...
# 2                         [seperti, gojek, gue, error]
# 3    [sementara, beralih, dulu, jd, grab, user, kar...
# 4    [lah, minggu, malah, sepi, order, tapi, sesepi...
# ..                                                 ...
# 402  [lah, kan, situ, yang, bolakbalik, jadi, yang,...
# 403  [malemmalem, otakku, berpikir, besok, naik, bu...
# 404        [betull, ak, selama, ada, grab, sih, jalan]
# 405  [rt, apa, perlu, aku, jadi, abang, grab, supay...
# 406  [tu, belum, ckp, pasal, transport, bas, dgn, g...
#
#                                     tweet_tokens_fdist  \
# 0    {'santai': 1, 'ada': 1, 'gojek': 1, 'chat': 1,...
# 1    {'prifad': 1, 'gua': 1, 'naek': 1, 'gojek': 1,...
# 2     {'seperti': 1, 'gojek': 1, 'gue': 1, 'error': 1}
# 3    {'sementara': 1, 'beralih': 1, 'dulu': 1, 'jd'...
# 4    {'lah': 1, 'minggu': 1, 'malah': 1, 'sepi': 1,...
# ..                                                 ...
# 402  {'lah': 1, 'kan': 1, 'situ': 2, 'yang': 2, 'bo...
# 403  {'malemmalem': 1, 'otakku': 1, 'berpikir': 1, ...
# 404  {'betull': 1, 'ak': 1, 'selama': 1, 'ada': 1, ...
# 405  {'rt': 1, 'apa': 1, 'perlu': 1, 'aku': 1, 'jad...
# 406  {'tu': 1, 'belum': 1, 'ckp': 1, 'pasal': 1, 't...
#
#                                       tweet_tokens_WSW  \
# 0    [santai, gojek, chat, worst, case, tinggal, fi...
# 1    [prifad, gua, naek, gojek, ye, semoga, turun, ...
# 2                                  [gojek, gue, error]
# 3    [beralih, grab, user, gojek, yahudi, kaget, ba...
# 4    [minggu, sepi, order, sesepi, gojek, food, cs,...
# ..                                                 ...
# 402  [situ, bolakbalik, keliatan, situ, gue, gue, d...
# 403  [malemmalem, otakku, berpikir, besok, bus, rut...
# 404                          [betull, ak, grab, jalan]
# 405             [abang, grab, jalan, pintas, hati, mu]
# 406  [ckp, pasal, transport, grab, taman, meyedihka...
#
#                                       tweet_normalized  \
# 0    [santai, gojek, chat, worst, case, tinggal, fi...
# 1    [prifad, gua, naik, gojek, ye, semoga, turun, ...
# 2                                  [gojek, gue, error]
# 3    [beralih, grab, user, gojek, yahudi, kaget, ba...
# 4    [minggu, sepi, order, sesepi, gojek, food, cs,...
# ..                                                 ...
# 402  [situ, bolakbalik, kelihatan, situ, gue, gue, ...
# 403  [malemmalem, otakku, berpikir, besok, bus, rut...
# 404                         [betull, aku, grab, jalan]
# 405             [abang, grab, jalan, pintas, hati, mu]
# 406  [cukup, pasal, transport, grab, taman, meyedih...
#
#                                               steeming
# 0    [santai, gojek, chat, worst, case, tinggal, fi...
# 1    [prifad, gua, naik, gojek, ye, moga, turun, du...
# 2                                  [gojek, gue, error]
# 3    [alih, grab, user, gojek, yahudi, kaget, baso,...
# 4    [minggu, sepi, order, sep, gojek, food, cs, pe...
# ..                                                 ...
# 402  [situ, bolakbalik, lihat, situ, gue, gue, dudu...
# 403  [malemmalem, otak, pikir, besok, bus, rute, ja...
# 404                         [betull, aku, grab, jalan]
# 405             [abang, grab, jalan, pintas, hati, mu]
# 406  [cukup, pasal, transport, grab, taman, meyedih...
#
# [407 rows x 9 columns]

# %%
from openpyxl import load_workbook
book = load_workbook('TextPreprocessing.xlsx')
writer = pd.ExcelWriter('TextPreprocessing.xlsx', engine='openpyxl')
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

df_preprocessed.to_excel(writer, index = False)

writer.save()
